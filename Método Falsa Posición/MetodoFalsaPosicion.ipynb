# %% [markdown]
# # Método de falsa posición
#
# En este cuaderno de trabajo implementaremos y analizaremos el método de bisección aplicada en ecuaciones algebráicas de una variable, lo anterior considerará que ya contamos con un primer intervalo de búsqueda.
#
# Recordando un poco sobre el método de bisección, para lo que consideraremos que contamos con una función $f$ y un intervalo de búsqueda $[a,b]$ este consiste en aplicar los siguientes pasos:
#
# - Validamos que el producto de los extremos del intervalo sea negativo $f(a) f(b) < 0$.
#
#
# - **Paso iterativo:** Calculamos el punto $c$ por medio del punto que intersecta al eje $x$ de la recta que une los puntos $(a,f(a))$ y $(b,f(b))$, la cual se encuentra dado por:
#
# $$c=b-f\left(b\right)\left[\frac{b-a}{f\left(b\right)-f\left(a\right)}\right]$$
#
#
# - Validamos que el producto del punto medio y el extremo izquierdo sea negativo $f(a) f(c) < 0$.
#
# - Si es cierto definimos $b =  c$, en caso contrario definimos $a = c$ y regresamos al paso iterativo.

# %%
# Importaremos las funciones a emplear necesarias para definir la ecuación algebraíca
from numpy import exp

# Condiciones de conlusion del método
tol = 1.*(10**(-10)) # Obtener un error relativo de 10^(-10)
maxItera = 100 # Realizar máximo 100 iteraciones

# %%
# Definimos la funcion objetivo
def fx(x):
    fx = 2 - exp(x)
    return fx

# %%
# Definimos el intervalo de busqueda inicial y validamos que funcione para el método
a = 0 # Extremo izquierdo
b = 1 # Extremo derecho
k = 0 # Inicilizamos las iteraciones
error = 10000 # Inicializamos el valor del error en un número muy grande
pmedioanterior = b # Inicializamos la primer aproximación como b

# %%
# Definimos el método iterativo
def itebiseccion(a,b,fx):
    
    # Calculamos el punto medio
    pmedio = b-fx(b)*((b-a)/(fx(b)-fx(a)))
    
    # Validamos que intervalo podemos emplear
    if fx(a)*fx(pmedio)<0:
        # Mandamos una bandera que aún no se ha encontrada la raíz y redefinimos b = punto medio
        return 1, a, pmedio, pmedio
    
    elif fx(pmedio)*fx(b)<0:
        # Mandamos una bandera que aún no se ha encontrada la raíz y redefinimos a = punto medio
        return 1, pmedio, b, pmedio
    
    else:
        # Mandamos una bandera que se ha encontrada la raíz y regresamos la raíz
        return 0, pmedio

# %%
# Empezamos el método de bisección verificando las diferentes condiciones sobre el intervalo para lo que se
# validan las posibilidades de la existencia de la raíz en el intervalo dado

# En este caso no existe una raíz en el intervalo
if fx(a)*fx(b)>0:
    # Se describe que no existe una raíz en el intervalo dado
    print('No existen raices de la funcion objetivo en el intervalo dado \n')

# En este caso se ha encontrado la raíz y esta puede estar en a o en b.
elif fx(a)*fx(b)==0:
    
    # La raíz se encuentra en el punto a
    if fx(a)==0:
        # Se describe que la raíz se encuentra en el punto a
        print('La raíz de la ecuación se encuentra en el punto: ', a)
        
    # Dado que la raíz no es a, entonces es b.
    else:
        # Se describe que la raíz se encuentra en el punto b
        print('La raíz de la ecuación se encuentra en el punto: ', b)

# Dado que existe una raíz en el intervalo comenzaremos el proceso iterativo
else:
    
    # Señalamos que iniciamos el proceso iterativo
    print('Iniciamos el proceso iterativo')
    
    # Iniciamos el proceso iterativo
    while (error > tol and k < maxItera):
        
        # Iteramos hasta satisfacer las condiciones o encontrar una raiz
        itera = itebiseccion(a,b,fx)
        
        # Validamos los casos obtenidos de la bandera, si esta es 0, se ha determinado la raíz
        if itera[0] == 0:
            # Describimos que hemos determinado la raíz y la imprimimos
            print('La raíz de la ecuación se encuentra en el punto: ', itera[1])
            
        # Validamos los casos obtenidos de la bandera, si esta es 1, no se ha determinado la raíz
        else:
            # Incrementamos en 1 las iteraciones realizadas
            k = k + 1
            
            # Imprimimos los resultados obtenidos de la iteracion
            print('Resultados de la iteracion: ', k)
            print('La aproximación de la raíz se encuentra dada por: ', itera[3])
            print('El valor de la función bajo la aproximación es: ', fx(itera[3]))
            print('El intervalor de búsqueda se ha reducido al [', itera[1], ' , ', itera[2], ' ]')
            
            # Actualizamos las variables
            a = itera[1]
            b = itera[2]
            error = abs(itera[3] - pmedioanterior)/pmedioanterior
            pmedioanterior = itera[3]
            
            # Imprimimos el error
            print('El error porcentual se encuentra dado por ', error, '\n')
# Out:
# Iniciamos el proceso iterativo
# Resultados de la iteracion:  1
# La aproximación de la raíz se encuentra dada por:  0.5819767068693265
# El valor de la función bajo la aproximación es:  0.21042760315816644
# El intervalor de búsqueda se ha reducido al [ 0.5819767068693265  ,  1  ]
# El error porcentual se encuentra dado por  0.41802329313067355
#
# Resultados de la iteracion:  2
# La aproximación de la raíz se encuentra dada por:  0.6766927037604051
# El valor de la función bajo la aproximación es:  0.032639682719065144
# El intervalor de búsqueda se ha reducido al [ 0.6766927037604051  ,  1  ]
# El error porcentual se encuentra dado por  0.1627487763223239
#
# Resultados de la iteracion:  3
# La aproximación de la raíz se encuentra dada por:  0.690745633944098
# El valor de la función bajo la aproximación es:  0.0047973304196899935
# El intervalor de búsqueda se ha reducido al [ 0.690745633944098  ,  1  ]
# El error porcentual se encuentra dado por  0.02076707803350071
#
# Resultados de la iteracion:  4
# La aproximación de la raíz se encuentra dada por:  0.6927974084413779
# El valor de la función bajo la aproximación es:  0.0006994219108622524
# El intervalor de búsqueda se ha reducido al [ 0.6927974084413779  ,  1  ]
# El error porcentual se encuentra dado por  0.0029703763533971755
#
# Resultados de la iteracion:  5
# La aproximación de la raíz se encuentra dada por:  0.6930962538194726
# El valor de la función bajo la aproximación es:  0.00010185088745662263
# El intervalor de búsqueda se ha reducido al [ 0.6930962538194726  ,  1  ]
# El error porcentual se encuentra dado por  0.00043136041569062243
#
# Resultados de la iteracion:  6
# La aproximación de la raíz se encuentra dada por:  0.6931397659701672
# El valor de la función bajo la aproximación es:  1.482912458006247e-05
# El intervalor de búsqueda se ha reducido al [ 0.6931397659701672  ,  1  ]
# El error porcentual se encuentra dado por  6.27793765366104e-05
#
# Resultados de la iteracion:  7
# La aproximación de la raíz se encuentra dada por:  0.6931461010527422
# El valor de la función bajo la aproximación es:  2.159013240854435e-06
# El intervalor de búsqueda se ha reducido al [ 0.6931461010527422  ,  1  ]
# El error porcentual se encuentra dado por  9.139689981722248e-06
#
# Resultados de la iteracion:  8
# La aproximación de la raíz se encuentra dada por:  0.6931470233921544
# El valor de la función bajo la aproximación es:  3.143355571388895e-07
# El intervalor de búsqueda se ha reducido al [ 0.6931470233921544  ,  1  ]
# El error porcentual se encuentra dado por  1.330656568331701e-06
#
# Resultados de la iteracion:  9
# La aproximación de la raíz se encuentra dada por:  0.6931471576775495
# El valor de la función bajo la aproximación es:  4.576479106788156e-08
# El intervalor de búsqueda se ha reducido al [ 0.6931471576775495  ,  1  ]
# El error porcentual se encuentra dado por  1.9373291755587865e-07
#
# Resultados de la iteracion:  10
# La aproximación de la raíz se encuentra dada por:  0.6931471772284483
# El valor de la función bajo la aproximación es:  6.662993934369865e-09
# El intervalor de búsqueda se ha reducido al [ 0.6931471772284483  ,  1  ]
# El error porcentual se encuentra dado por  2.820598565866945e-08
#
# Resultados de la iteracion:  11
# La aproximación de la raíz se encuentra dada por:  0.6931471800749055
# El valor de la función bajo la aproximación es:  9.70079572226723e-10
# El intervalor de búsqueda se ha reducido al [ 0.6931471800749055  ,  1  ]
# El error porcentual se encuentra dado por  4.10656967897228e-09
#
# Resultados de la iteracion:  12
# La aproximación de la raíz se encuentra dada por:  0.6931471804893272
# El valor de la función bajo la aproximación es:  1.412361338992696e-10
# El intervalor de búsqueda se ha reducido al [ 0.6931471804893272  ,  1  ]
# El error porcentual se encuentra dado por  5.978841594925654e-10
#
# Resultados de la iteracion:  13
# La aproximación de la raíz se encuentra dada por:  0.6931471805496638
# El valor de la función bajo la aproximación es:  2.0562884728292374e-11
# El intervalor de búsqueda se ha reducido al [ 0.6931471805496638  ,  1  ]
# El error porcentual se encuentra dado por  8.704734908233194e-11
