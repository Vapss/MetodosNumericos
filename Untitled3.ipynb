# %%
# Importamos las funciones necesarias que empleara la función objetivo
import math
from math import e, cos, sin, exp, log

# Procedemos a definir e inicializar las condiciones de paro del método
tol = 1.*(10**(-15)) # Obtener un error relativo de 10^(-10)
maxItera = 100000 # Realizar máximo 100 iteraciones

# %%
# Definimos la funcion objetivo
def fx(x):
    fx = cos(2*x)-(4*x)*cos(x)+(2*x)**2+1
    return fx

# Definimos la derivada de la funcion objetivo
def fxp(x):
    fxp = -2*sin(2*x)+(4*x)*sin(x)-(4*cos(x))+4*x
    return fxp

# %%
# Definimos el punto inicial donde comenzaremos por aplicar el método así como el indice de conteo de las
# iteraciones y un error grande a fin de inicializar el método
p0 = 0.5 # aproximación inicial
k = 0 # Inicilizamos las iteraciones
error = 10000 # Inicializamos el valor del error en un número muy grande
pAnterior = p0 # Inicializamos la primer aproximación como b

# %%
# Definimos una funcion que defina el método iterativo del punto fijo
def itenewton(a, fx, fxp):
    # Evaluamos para validar si ya tenemos la raíz
    evalua = fx(a)
    # Validamos si llegamos a las raíz
    if evalua==0:
        return 0, a
    
    else:
        return 1, a - (fx(a) / fxp(a))

# %%
# Empezamos el método de newton con los datos dados

# En este caso ya tenemos la raíz deseada
if fx(p0) == 0:
    # Se describe que existe una raíz en el punto dado previamente
    print('Se ha encontrado el punto fijo, el cual está dado por el punto {0}.'.format(p0))
    
# Dado que no tenemos la raíz aún procedemos a realizar iteraciones
else:
    # Señalamos que iniciamos el proceso iterativo
    print('Iniciamos el proceso iterativo')
    
    # Iniciamos el proceso iterativo
    while (error > tol and k < maxItera):
        
        # Iteramos el proceso
        itera = itenewton(p0, fx, fxp)
        
        # Validamos los casos obtenidos de la bandera, si esta es 0, se ha determinado la raíz
        if itera[0] == 0:
            # Describimos que hemos determinado el punto fijo y lo imprimimos
            print('El punto fijo de la función se encuentra en el punto: {0}.'.format(itera[1]))
            k = maxItera
            
        # Validamos los casos obtenidos de la bandera, si esta es 1, no se ha determinado el punto fijo
        else:
            # Incrementamos en 1 las iteraciones realizadas
            k = k + 1
            
            # Imprimimos los resultados obtenidos de la iteracion
            print('Resultados de la iteracion {0}.'.format(k))
            print('La aproximación del punto fijo se encuentra dada por {0}.'.format(itera[1]))
            print('El valor de la función bajo la aproximación es {0}.'.format(fx(itera[1])))
            
            # Actualizamos las variables
            error = abs(p0 - itera[1]) + abs(fx(p0)) # Error de aproximaciones
            p0 = itera[1]
            
            # Imprimimos el error
            print('El error relativo se encuentra dado por {0}.\n'.format(error))
# Out:
# Iniciamos el proceso iterativo
# Resultados de la iteracion 1.
# La aproximación del punto fijo se encuentra dada por 0.851382811432911.
# El valor de la función bajo la aproximación es 1.5237710556251605.
# El error relativo se encuentra dado por 1.1365199935203052.
#
# Resultados de la iteracion 2.
# La aproximación del punto fijo se encuentra dada por -0.27837270117487756.
# El valor de la función bajo la aproximación es 3.229570588900411.
# El error relativo se encuentra dado por 2.653526568232949.
#
# Resultados de la iteracion 3.
# La aproximación del punto fijo se encuentra dada por 0.6195591213946632.
# El valor de la función bajo la aproximación es 0.8434261996026726.
# El error relativo se encuentra dado por 4.127502411469951.
#
# Resultados de la iteracion 4.
# La aproximación del punto fijo se encuentra dada por 1.3051360245875998.
# El valor de la función bajo la aproximación es 5.58074607023074.
# El error relativo se encuentra dado por 1.5290031027956092.
#
# Resultados de la iteracion 5.
# La aproximación del punto fijo se encuentra dada por 0.6240935963192963.
# El valor de la función bajo la aproximación es 0.8492227973526598.
# El error relativo se encuentra dado por 6.261788498499043.
#
# Resultados de la iteracion 6.
# La aproximación del punto fijo se encuentra dada por 1.3391474617906747.
# El valor de la función bajo la aproximación es 6.048899959371307.
# El error relativo se encuentra dado por 1.5642766628240383.
#
# Resultados de la iteracion 7.
# La aproximación del punto fijo se encuentra dada por 0.6484736226684886.
# El valor de la función bajo la aproximación es 0.8851601774030353.
# El error relativo se encuentra dado por 6.739573798493494.
#
# Resultados de la iteracion 8.
# La aproximación del punto fijo se encuentra dada por 1.5773171350435247.
# El valor de la función bajo la aproximación es 9.992943657460172.
# El error relativo se encuentra dado por 1.8140036897780714.
#
# Resultados de la iteracion 9.
# La aproximación del punto fijo se encuentra dada por 0.7886434721663432.
# El valor de la función bajo la aproximación es 1.2579737306868575.
# El error relativo se encuentra dado por 10.781617320337354.
#
# Resultados de la iteracion 10.
# La aproximación del punto fijo se encuentra dada por -1.4058893291467034.
# El valor de la función bajo la aproximación es 8.88316311545756.
# El error relativo se encuentra dado por 3.452506531999904.
#
# Resultados de la iteracion 11.
# La aproximación del punto fijo se encuentra dada por 102.85716150617957.
# El valor de la función bajo la aproximación es 42601.390031080366.
# El error relativo se encuentra dado por 113.14621395078383.
#
# Resultados de la iteracion 12.
# La aproximación del punto fijo se encuentra dada por 43.331930849159484.
# El valor de la función bajo la aproximación es 7373.9467575049675.
# El error relativo se encuentra dado por 42660.915261737384.
#
# Resultados de la iteracion 13.
# La aproximación del punto fijo se encuentra dada por -66.52093698084371.
# El valor de la función bajo la aproximación es 17474.407170824437.
# El error relativo se encuentra dado por 7483.799625334971.
#
# Resultados de la iteracion 14.
# La aproximación del punto fijo se encuentra dada por -22.76925037542363.
# El valor de la función bajo la aproximación es 2009.900301605796.
# El error relativo se encuentra dado por 17518.15885742986.
#
# Resultados de la iteracion 15.
# La aproximación del punto fijo se encuentra dada por -9.383995120869482.
# El valor de la función bajo la aproximación es 316.7293639406083.
# El error relativo se encuentra dado por 2023.28555686035.
#
# Resultados de la iteracion 16.
# La aproximación del punto fijo se encuentra dada por 0.46092490559997223.
# El valor de la función bajo la aproximación es 0.8028605794529926.
# El error relativo se encuentra dado por 326.5742839670778.
#
# Resultados de la iteracion 17.
# La aproximación del punto fijo se encuentra dada por 0.7805001993427466.
# El valor de la función bajo la aproximación es 1.2281439183483696.
# El error relativo se encuentra dado por 1.122435873195767.
#
# Resultados de la iteracion 18.
# La aproximación del punto fijo se encuentra dada por -1.796391900023143.
# El valor de la función bajo la aproximación es 11.40084985303243.
# El error relativo se encuentra dado por 3.8050360177142593.
#
# Resultados de la iteracion 19.
# La aproximación del punto fijo se encuentra dada por 69.72591035756919.
# El valor de la función bajo la aproximación es 19219.688898488865.
# El error relativo se encuentra dado por 82.92315211062476.
#
# Resultados de la iteracion 20.
# La aproximación del punto fijo se encuentra dada por 25.412502378120173.
# El valor de la función bajo la aproximación es 2487.330615890297.
# El error relativo se encuentra dado por 19264.002306468312.
#
# Resultados de la iteracion 21.
# La aproximación del punto fijo se encuentra dada por 5.483913696366077.
# El valor de la función bajo la aproximación es 105.97131887840045.
# El error relativo se encuentra dado por 2507.259204572051.
#
# Resultados de la iteracion 22.
# La aproximación del punto fijo se encuentra dada por -14.062836014706402.
# El valor de la función bajo la aproximación es 795.2418222625398.
# El error relativo se encuentra dado por 125.51806858947293.
#
# Resultados de la iteracion 23.
# La aproximación del punto fijo se encuentra dada por 5078.891813011885.
# El valor de la función bajo la aproximación es 103190438.15043586.
# El error relativo se encuentra dado por 5888.196471289131.
#
# Resultados de la iteracion 24.
# La aproximación del punto fijo se encuentra dada por 2368.7980641879217.
# El valor de la función bajo la aproximación es 22435350.437088717.
# El error relativo se encuentra dado por 103193148.24418469.
#
# Resultados de la iteracion 25.
# La aproximación del punto fijo se encuentra dada por 84.9471657546228.
# El valor de la función bajo la aproximación es 29203.226015615764.
# El error relativo se encuentra dado por 22437634.28798715.
#
# Resultados de la iteracion 26.
# La aproximación del punto fijo se encuentra dada por -12.013903405902468.
# El valor de la función bajo la aproximación es 619.6911861442217.
# El error relativo se encuentra dado por 29300.18708477629.
#
# Resultados de la iteracion 27.
# La aproximación del punto fijo se encuentra dada por -4.116374818044606.
# El valor de la función bajo la aproximación es 59.16550976001345.
# El error relativo se encuentra dado por 627.5887147320796.
#
# Resultados de la iteracion 28.
# La aproximación del punto fijo se encuentra dada por -1.8397604516902617.
# El valor de la función bajo la aproximación es 11.72456220720969.
# El error relativo se encuentra dado por 61.442124126367794.
#
# Resultados de la iteracion 29.
# La aproximación del punto fijo se encuentra dada por 49.95493969009259.
# El valor de la función bajo la aproximación es 9793.535294170693.
# El error relativo se encuentra dado por 63.51926234899254.
#
# Resultados de la iteracion 30.
# La aproximación del punto fijo se encuentra dada por -21.995559602758803.
# El valor de la función bajo la aproximación es 1849.2371475700138.
# El error relativo se encuentra dado por 9865.485793463544.
#
# Resultados de la iteracion 31.
# La aproximación del punto fijo se encuentra dada por -0.07288711553791671.
# El valor de la función bajo la aproximación es 2.3014182399573935.
# El error relativo se encuentra dado por 1871.1598200572346.
#
# Resultados de la iteracion 32.
# La aproximación del punto fijo se encuentra dada por 0.5069350027604421.
# El valor de la función bajo la aproximación es 0.7837872204005565.
# El error relativo se encuentra dado por 2.881240358255752.
#
# Resultados de la iteracion 33.
# La aproximación del punto fijo se encuentra dada por 0.8660575177855163.
# El valor de la función bajo la aproximación es 1.595353486324786.
# El error relativo se encuentra dado por 1.1429097354256306.
#
# Resultados de la iteracion 34.
# La aproximación del punto fijo se encuentra dada por -0.17134014859006386.
# El valor de la función bajo la aproximación es 2.734612185443115.
# El error relativo se encuentra dado por 2.632751152700366.
#
# Resultados de la iteracion 35.
# La aproximación del punto fijo se encuentra dada por 0.5411866867531299.
# El valor de la función bajo la aproximación es 0.7853659239719544.
# El error relativo se encuentra dado por 3.4471390207863086.
#
# Resultados de la iteracion 36.
# La aproximación del punto fijo se encuentra dada por 0.9513816444412927.
# El valor de la función bajo la aproximación es 2.0852734033168963.
# El error relativo se encuentra dado por 1.1955608816601173.
#
# Resultados de la iteracion 37.
# La aproximación del punto fijo se encuentra dada por 0.17647956474858761.
# El valor de la función bajo la aproximación es 1.3679802340488358.
# El error relativo se encuentra dado por 2.860175483009601.
#
# Resultados de la iteracion 38.
# La aproximación del punto fijo se encuentra dada por 0.536533985731482.
# El valor de la función bajo la aproximación es 0.7843328337043858.
# El error relativo se encuentra dado por 1.7280346550317303.
#
# Resultados de la iteracion 39.
# La aproximación del punto fijo se encuentra dada por 0.9383179216047206.
# El valor de la función bajo la aproximación es 2.001938332925287.
# El error relativo se encuentra dado por 1.1861167695776245.
#
# Resultados de la iteracion 40.
# La aproximación del punto fijo se encuentra dada por 0.14033792878709972.
# El valor de la función bajo la aproximación es 1.483814433588074.
# El error relativo se encuentra dado por 2.7999183257429077.
#
# Resultados de la iteracion 41.
# La aproximación del punto fijo se encuentra dada por 0.5232762563695481.
# El valor de la función bajo la aproximación es 0.7828111136737252.
# El error relativo se encuentra dado por 1.8667527611705226.
#
# Resultados de la iteracion 42.
# La aproximación del punto fijo se encuentra dada por 0.9038212450704368.
# El valor de la función bajo la aproximación es 1.796474138342337.
# El error relativo se encuentra dado por 1.163356102374614.
#
# Resultados de la iteracion 43.
# La aproximación del punto fijo se encuentra dada por 0.021980903194303236.
# El valor de la función bajo la aproximación es 1.9130641027881587.
# El error relativo se encuentra dado por 2.6783144802184706.
#
# Resultados de la iteracion 44.
# La aproximación del punto fijo se encuentra dada por 0.5005971664109414.
# El valor de la función bajo la aproximación es 0.784999232134306.
# El error relativo se encuentra dado por 2.391680366004797.
#
# Resultados de la iteracion 45.
# La aproximación del punto fijo se encuentra dada por 0.8526176530348363.
# El valor de la función bajo la aproximación es 1.529654658012725.
# El error relativo se encuentra dado por 1.137019718758201.
#
# Resultados de la iteracion 46.
# La aproximación del punto fijo se encuentra dada por -0.2683673707315485.
# El valor de la función bajo la aproximación es 3.182511809923526.
# El error relativo se encuentra dado por 2.6506396817791096.
#
# Resultados de la iteracion 47.
# La aproximación del punto fijo se encuentra dada por 0.6100549608955608.
# El valor de la función bajo la aproximación es 0.8321662142063919.
# El error relativo se encuentra dado por 4.060934141550635.
#
# Resultados de la iteracion 48.
# La aproximación del punto fijo se encuentra dada por 1.2412068376774672.
# El valor de la función bajo la aproximación es 4.764992897161536.
# El error relativo se encuentra dado por 1.4633180909882983.
#
# Resultados de la iteracion 49.
# La aproximación del punto fijo se encuentra dada por 0.5741089995381671.
# El valor de la función bajo la aproximación es 0.800254509238469.
# El error relativo se encuentra dado por 5.432090735300836.
#
# Resultados de la iteracion 50.
# La aproximación del punto fijo se encuentra dada por 1.0623146461630637.
# El valor de la función bajo la aproximación es 2.9193402963855215.
# El error relativo se encuentra dado por 1.2884601558633655.
#
# Resultados de la iteracion 51.
# La aproximación del punto fijo se encuentra dada por 0.3853638209188476.
# El valor de la función bajo la aproximación es 0.8830174126704537.
# El error relativo se encuentra dado por 3.5962911216297377.
#
# Resultados de la iteracion 52.
# La aproximación del punto fijo se encuentra dada por 0.681769977409467.
# El valor de la función bajo la aproximación es 0.9475524564669546.
# El error relativo se encuentra dado por 1.1794235691610733.
#
# Resultados de la iteracion 53.
# La aproximación del punto fijo se encuentra dada por 2.2164337525086912.
# El valor de la función bajo la aproximación es 25.70899946050535.
# El error relativo se encuentra dado por 2.482216231566179.
#
# Resultados de la iteracion 54.
# La aproximación del punto fijo se encuentra dada por 0.9484908194307957.
# El valor de la función bajo la aproximación es 2.066568314651232.
# El error relativo se encuentra dado por 26.976942393583244.
#
# Resultados de la iteracion 55.
# La aproximación del punto fijo se encuentra dada por 0.16880509690040668.
# El valor de la función bajo la aproximación es 1.3919066317267375.
# El error relativo se encuentra dado por 2.846254037181621.
#
# Resultados de la iteracion 56.
# La aproximación del punto fijo se encuentra dada por 0.5334696550459322.
# El valor de la función bajo la aproximación es 0.7837946989325548.
# El error relativo se encuentra dado por 1.756571189872263.
#
# Resultados de la iteracion 57.
# La aproximación del punto fijo se encuentra dada por 0.9299988187039865.
# El valor de la función bajo la aproximación es 1.9504613045128658.
# El error relativo se encuentra dado por 1.1803238625906092.
#
# Resultados de la iteracion 58.
# La aproximación del punto fijo se encuentra dada por 0.11517836853229513.
# El valor de la función bajo la aproximación es 1.5689883058618501.
# El error relativo se encuentra dado por 2.7652817546845574.
#
# Resultados de la iteracion 59.
# La aproximación del punto fijo se encuentra dada por 0.5157895600556169.
# El valor de la función bajo la aproximación es 0.7828711978364362.
# El error relativo se encuentra dado por 1.9695994973851718.
#
# Resultados de la iteracion 60.
# La aproximación del punto fijo se encuentra dada por 0.8859268887598373.
# El valor de la función bajo la aproximación es 1.6981104087101904.
# El error relativo se encuentra dado por 1.1530085265406567.
#
# Resultados de la iteracion 61.
# La aproximación del punto fijo se encuentra dada por -0.058351521903617365.
# El valor de la función bajo la aproximación es 2.239826363748847.
# El error relativo se encuentra dado por 2.642388819373645.
#
# Resultados de la iteracion 62.
# La aproximación del punto fijo se encuentra dada por 0.5044034080849727.
# El valor de la función bajo la aproximación es 0.7842159698048421.
# El error relativo se encuentra dado por 2.802581293737437.
#
# Resultados de la iteracion 63.
# La aproximación del punto fijo se encuentra dada por 0.8606144754824046.
# El valor de la función bajo la aproximación es 1.568378191925297.
# El error relativo se encuentra dado por 1.140427037202274.
#
# Resultados de la iteracion 64.
# La aproximación del punto fijo se encuentra dada por -0.2082149721745603.
# El valor de la función bajo la aproximación es 2.902824078140127.
# El error relativo se encuentra dado por 2.637207639582262.
#
# Resultados de la iteracion 65.
# La aproximación del punto fijo se encuentra dada por 0.5627247853221412.
# El valor de la función bajo la aproximación es 0.7935867301353745.
# El error relativo se encuentra dado por 3.6737638356368287.
#
# Resultados de la iteracion 66.
# La aproximación del punto fijo se encuentra dada por 1.0197537869662832.
# El valor de la función bajo la aproximación es 2.572180889603267.
# El error relativo se encuentra dado por 1.2506157317795163.
#
# Resultados de la iteracion 67.
# La aproximación del punto fijo se encuentra dada por 0.319963553833308.
# El valor de la función bajo la aproximación es 0.9967483662769996.
# El error relativo se encuentra dado por 3.2719711227362422.
#
# Resultados de la iteracion 68.
# La aproximación del punto fijo se encuentra dada por 0.6212004499716423.
# El valor de la función bajo la aproximación es 0.8454925749870781.
# El error relativo se encuentra dado por 1.2979852624153339.
#
# Resultados de la iteracion 69.
# La aproximación del punto fijo se encuentra dada por 1.3171604821581449.
# El valor de la función bajo la aproximación es 5.743539118506807.
# El error relativo se encuentra dado por 1.5414526071735808.
#
# Resultados de la iteracion 70.
# La aproximación del punto fijo se encuentra dada por 0.6328708077830788.
# El valor de la función bajo la aproximación es 0.8612290855198736.
# El error relativo se encuentra dado por 6.427828792881873.
#
# Resultados de la iteracion 71.
# La aproximación del punto fijo se encuentra dada por 1.4128049630575688.
# El valor de la función bajo la aproximación es 7.144445855452188.
# El error relativo se encuentra dado por 1.6411632407943637.
#
# Resultados de la iteracion 72.
# La aproximación del punto fijo se encuentra dada por 0.6970157290938741.
# El valor de la función bajo la aproximación es 0.9813907421793344.
# El error relativo se encuentra dado por 7.860235089415883.
#
# Resultados de la iteracion 73.
# La aproximación del punto fijo se encuentra dada por 2.8394627265028287.
# El valor de la función bajo la aproximación es 44.91651289582164.
# El error relativo se encuentra dado por 3.1238377395882893.
#
# Resultados de la iteracion 74.
# La aproximación del punto fijo se encuentra dada por 0.558574641258089.
# El valor de la función bajo la aproximación es 0.7915585123219642.
# El error relativo se encuentra dado por 47.19740098106638.
#
# Resultados de la iteracion 75.
# La aproximación del punto fijo se encuentra dada por 1.0054477118836025.
# El valor de la función bajo la aproximación es 2.463156825883652.
# El error relativo se encuentra dado por 1.2384315829474777.
#
# Resultados de la iteracion 76.
# La aproximación del punto fijo se encuentra dada por 0.2946904794310057.
# El valor de la función bajo la aproximación es 1.0507068940147217.
# El error relativo se encuentra dado por 3.1739140583362486.
#
# Resultados de la iteracion 77.
# La aproximación del punto fijo se encuentra dada por 0.6020822971084945.
# El valor de la función bajo la aproximación es 0.8236414855106455.
# El error relativo se encuentra dado por 1.3580987116922105.
#
# Resultados de la iteracion 78.
# La aproximación del punto fijo se encuentra dada por 1.1940329356862347.
# El valor de la función bajo la aproximación es 4.216378234960352.
# El error relativo se encuentra dado por 1.4155921240883858.
#
# Resultados de la iteracion 79.
# La aproximación del punto fijo se encuentra dada por 0.5328669587098643.
# El valor de la función bajo la aproximación es 0.7837021049205324.
# El error relativo se encuentra dado por 4.877544211936723.
#
# Resultados de la iteracion 80.
# La aproximación del punto fijo se encuentra dada por 0.9283881776063116.
# El valor de la función bajo la aproximación es 1.9406373358599804.
# El error relativo se encuentra dado por 1.1792233238169798.
#
# Resultados de la iteracion 81.
# La aproximación del punto fijo se encuentra dada por 0.11009109181852761.
# El valor de la función bajo la aproximación es 1.5866394265029955.
# El error relativo se encuentra dado por 2.7589344216477647.
#
# Resultados de la iteracion 82.
# La aproximación del punto fijo se encuentra dada por 0.5144486518076389.
# El valor de la función bajo la aproximación es 0.7829513242422279.
# El error relativo se encuentra dado por 1.9909969864921067.
#
# Resultados de la iteracion 83.
# La aproximación del punto fijo se encuentra dada por 0.8828312311074693.
# El valor de la función bajo la aproximación es 1.6816558611291579.
# El error relativo se encuentra dado por 1.1513339035420582.
#
# Resultados de la iteracion 84.
# La aproximación del punto fijo se encuentra dada por -0.07406830552302124.
# El valor de la función bajo la aproximación es 2.306453177308553.
# El error relativo se encuentra dado por 2.6385553977596485.
#
# Resultados de la iteracion 85.
# La aproximación del punto fijo se encuentra dada por 0.5071671481432378.
# El valor de la función bajo la aproximación es 0.7837516031292957.
# El error relativo se encuentra dado por 2.887688630974812.
#
# Resultados de la iteracion 86.
# La aproximación del punto fijo se encuentra dada por 0.8665617434985196.
# El valor de la función bajo la aproximación es 1.597877818506737.
# El error relativo se encuentra dado por 1.1431461984845774.
#
# Resultados de la iteracion 87.
# La aproximación del punto fijo se encuentra dada por -0.1680726887187649.
# El valor de la función bajo la aproximación es 2.719844348261663.
# El error relativo se encuentra dado por 2.6325122507240213.
#
# Resultados de la iteracion 88.
# La aproximación del punto fijo se encuentra dada por 0.5395267063356282.
# El valor de la función bajo la aproximación es 0.7849673703995286.
# El error relativo se encuentra dado por 3.427443743316056.
#
# Resultados de la iteracion 89.
# La aproximación del punto fijo se encuentra dada por 0.9466591823819319.
# El valor de la función bajo la aproximación es 2.0547945418577362.
# El error relativo se encuentra dado por 1.1920998464458323.
#
# Resultados de la iteracion 90.
# La aproximación del punto fijo se encuentra dada por 0.16385128548116723.
# El valor de la función bajo la aproximación es 1.4075463902401877.
# El error relativo se encuentra dado por 2.837602438758501.
#
# Resultados de la iteracion 91.
# La aproximación del punto fijo se encuentra dada por 0.5315634123958033.
# El valor de la función bajo la aproximación es 0.7835166977415164.
# El error relativo se encuentra dado por 1.7752585171548239.
#
# Resultados de la iteracion 92.
# La aproximación del punto fijo se encuentra dada por 0.924932666781555.
# El valor de la función bajo la aproximación es 1.91971611834287.
# El error relativo se encuentra dado por 1.176885952127268.
#
# Resultados de la iteracion 93.
# La aproximación del punto fijo se encuentra dada por 0.09892302354838889.
# El valor de la función bajo la aproximación es 1.6258776890608782.
# El error relativo se encuentra dado por 2.745725761576036.
#
# Resultados de la iteracion 94.
# La aproximación del punto fijo se encuentra dada por 0.5117092314776521.
# El valor de la función bajo la aproximación es 0.7831801699181109.
# El error relativo se encuentra dado por 2.0386638969901414.
#
# Resultados de la iteracion 95.
# La aproximación del punto fijo se encuentra dada por 0.8766050691368943.
# El valor de la función bajo la aproximación es 1.649060209732656.
# El error relativo se encuentra dado por 1.148076007577353.
#
# Resultados de la iteracion 96.
# La aproximación del punto fijo se encuentra dada por -0.10762596421857462.
# El valor de la función bajo la aproximación es 2.4512689322957035.
# El error relativo se encuentra dado por 2.633291243088125.
#
# Resultados de la iteracion 97.
# La aproximación del punto fijo se encuentra dada por 0.515483729393523.
# El valor de la función bajo la aproximación es 0.7828876245050373.
# El error relativo se encuentra dado por 3.0743786259078014.
#
# Resultados de la iteracion 98.
# La aproximación del punto fijo se encuentra dada por 0.8852180149367772.
# El valor de la función bajo la aproximación es 1.6943279184062097.
# El error relativo se encuentra dado por 1.1526219100482915.
#
# Resultados de la iteracion 99.
# La aproximación del punto fijo se encuentra dada por -0.061897088990202076.
# El valor de la función bajo la aproximación es 2.2547865008718313.
# El error relativo se encuentra dado por 2.641443022333189.
#
# Resultados de la iteracion 100.
# La aproximación del punto fijo se encuentra dada por 0.5049659439052557.
# El valor de la función bajo la aproximación es 0.7841143200402578.
# El error relativo se encuentra dado por 2.821649533767289.
#
# Resultados de la iteracion 101.
# La aproximación del punto fijo se encuentra dada por 0.8618152230304014.
# El valor de la función bajo la aproximación es 1.5742858609013308.
# El error relativo se encuentra dado por 1.1409635991654035.
#
# Resultados de la iteracion 102.
# La aproximación del punto fijo se encuentra dada por -0.19981827995907675.
# El valor de la función bajo la aproximación es 2.8642815573279754.
# El error relativo se encuentra dado por 2.635919363890809.
#
# Resultados de la iteracion 103.
# La aproximación del punto fijo se encuentra dada por 0.5573536868797506.
# El valor de la función bajo la aproximación es 0.7910024695063527.
# El error relativo se encuentra dado por 3.6214535241668027.
#
# Resultados de la iteracion 104.
# La aproximación del punto fijo se encuentra dada por 1.0013507642542505.
# El valor de la función bajo la aproximación es 2.4326377266353068.
# El error relativo se encuentra dado por 1.2349995468808526.
#
# Resultados de la iteracion 105.
# La aproximación del punto fijo se encuentra dada por 0.28707770793913445.
# El valor de la función bajo la aproximación es 1.0679890671717702.
# El error relativo se encuentra dado por 3.146910782950423.
#
# Resultados de la iteracion 106.
# La aproximación del punto fijo se encuentra dada por 0.5967207627795044.
# El valor de la función bajo la aproximación es 0.8183768115888426.
# El error relativo se encuentra dado por 1.3776321220121401.
#
# Resultados de la iteracion 107.
# La aproximación del punto fijo se encuentra dada por 1.1650913430915901.
# El valor de la función bajo la aproximación es 3.9019841999912375.
# El error relativo se encuentra dado por 1.3867473919009283.
#
# Resultados de la iteracion 108.
# La aproximación del punto fijo se encuentra dada por 0.5052187807862901.
# El valor de la función bajo la aproximación es 0.7840698189101416.
# El error relativo se encuentra dado por 4.561856762296538.
#
# Resultados de la iteracion 109.
# La aproximación del punto fijo se encuentra dada por 0.8623565233022978.
# El valor de la función bajo la aproximación es 1.576957032987734.
# El error relativo se encuentra dado por 1.1412075614261492.
#
# Resultados de la iteracion 110.
# La aproximación del punto fijo se encuentra dada por -0.1960829900936465.
# El valor de la función bajo la aproximación es 2.847179567126142.
# El error relativo se encuentra dado por 2.6353965463836784.
#
# Resultados de la iteracion 111.
# La aproximación del punto fijo se encuentra dada por 0.5550548663443072.
# El valor de la función bajo la aproximación es 0.790005536739872.
# El error relativo se encuentra dado por 3.598317423564096.
#
# Resultados de la iteracion 112.
# La aproximación del punto fijo se encuentra dada por 0.9937693244643188.
# El valor de la función bajo la aproximación es 2.3769834670880283.
# El error relativo se encuentra dado por 1.2287199948598835.
#
# Resultados de la iteracion 113.
# La aproximación del punto fijo se encuentra dada por 0.2725050319172039.
# El valor de la función bajo la aproximación es 1.1023599825940409.
# El error relativo se encuentra dado por 3.098247759635143.
#
# Resultados de la iteracion 114.
# La aproximación del punto fijo se encuentra dada por 0.5869386879588209.
# El valor de la función bajo la aproximación es 0.8097322942166454.
# El error relativo se encuentra dado por 1.4167936386356579.
#
# Resultados de la iteracion 115.
# La aproximación del punto fijo se encuentra dada por 1.117181537991999.
# El valor de la función bajo la aproximación es 3.4181732050298157.
# El error relativo se encuentra dado por 1.3399751442498236.
#
# Resultados de la iteracion 116.
# La aproximación del punto fijo se encuentra dada por 0.4543664462167609.
# El valor de la función bajo la aproximación es 0.8074767312601779.
# El error relativo se encuentra dado por 4.080988296805054.
#
# Resultados de la iteracion 117.
# La aproximación del punto fijo se encuentra dada por 0.7702227160196622.
# El valor de la función bajo la aproximación es 1.1919916586928312.
# El error relativo se encuentra dado por 1.123333001063079.
#
# Resultados de la iteracion 118.
# La aproximación del punto fijo se encuentra dada por -2.5780800026926083.
# El valor de la función bajo la aproximación es 19.297463764053006.
# El error relativo se encuentra dado por 4.540294377405102.
#
# Resultados de la iteracion 119.
# La aproximación del punto fijo se encuentra dada por 3.3988777809285327.
# El valor de la función bajo la aproximación es 61.227991116175346.
# El error relativo se encuentra dado por 25.274421547674148.
#
# Resultados de la iteracion 120.
# La aproximación del punto fijo se encuentra dada por -1.3037084089064819.
# El valor de la función bajo la aproximación es 8.31425227488117.
# El error relativo se encuentra dado por 65.93057730601036.
#
# Resultados de la iteracion 121.
# La aproximación del punto fijo se encuentra dada por 36.092177793125664.
# El valor de la función bajo la aproximación es 5215.7998231821075.
# El error relativo se encuentra dado por 45.710138476913315.
#
# Resultados de la iteracion 122.
# La aproximación del punto fijo se encuentra dada por -55244.029707849724.
# El valor de la función bajo la aproximación es 12207469986.696392.
# El error relativo se encuentra dado por 60495.92170882496.
#
# Resultados de la iteracion 123.
# La aproximación del punto fijo se encuentra dada por 183795.27174332665.
# El valor de la función bajo la aproximación es 135122150496.30835.
# El error relativo se encuentra dado por 12207709025.997843.
#
# Resultados de la iteracion 124.
# La aproximación del punto fijo se encuentra dada por -149348.05794996428.
# El valor de la función bajo la aproximación es 89218776223.69232.
# El error relativo se encuentra dado por 135122483639.63805.
#
# Resultados de la iteracion 125.
# La aproximación del punto fijo se encuentra dada por 19398.104785331438.
# El valor de la función bajo la aproximación es 1505171822.5146158.
# El error relativo se encuentra dado por 89218944969.85506.
#
# Resultados de la iteracion 126.
# La aproximación del punto fijo se encuentra dada por 9411.636087164838.
# El valor de la función bajo la aproximación es 354283994.3681985.
# El error relativo se encuentra dado por 1505181808.983314.
#
# Resultados de la iteracion 127.
# La aproximación del punto fijo se encuentra dada por -11239.547933986256.
# El valor de la función bajo la aproximación es 505331314.11939996.
# El error relativo se encuentra dado por 354304645.5522197.
#
# Resultados de la iteracion 128.
# La aproximación del punto fijo se encuentra dada por -5253.037636349258.
# El valor de la función bajo la aproximación es 110397725.65003185.
# El error relativo se encuentra dado por 505337300.6296976.
#
# Resultados de la iteracion 129.
# La aproximación del punto fijo se encuentra dada por 2150.5236430945833.
# El valor de la función bajo la aproximación es 18499896.26543068.
# El error relativo se encuentra dado por 110405129.2113113.
#
# Resultados de la iteracion 130.
# La aproximación del punto fijo se encuentra dada por 1072.3786324056864.
# El valor de la función bajo la aproximación es 4601946.890756678.
# El error relativo se encuentra dado por 18500974.41044137.
#
# Resultados de la iteracion 131.
# La aproximación del punto fijo se encuentra dada por -8603.888398358315.
# El valor de la función bajo la aproximación es 296087115.3974727.
# El error relativo se encuentra dado por 4611623.157787442.
#
# Resultados de la iteracion 132.
# La aproximación del punto fijo se encuentra dada por 35278.588700328095.
# El valor de la función bajo la aproximación es 4978304850.26871.
# El error relativo se encuentra dado por 296130997.8745714.
#
# Resultados de la iteracion 133.
# La aproximación del punto fijo se encuentra dada por -12856505.062984232.
# El valor de la función bajo la aproximación es 661158864494830.2.
# El error relativo se encuentra dado por 4991196633.920395.
#
# Resultados de la iteracion 134.
# La aproximación del punto fijo se encuentra dada por 86987918.67330228.
# El valor de la función bajo la aproximación es 3.02675919719963e+16.
# El error relativo se encuentra dado por 661158964339254.0.
#
# Resultados de la iteracion 135.
# La aproximación del punto fijo se encuentra dada por 43487535.72192508.
# El valor de la función bajo la aproximación es 7564663077745713.0.
# El error relativo se encuentra dado por 3.0267592015496684e+16.
#
# Resultados de la iteracion 136.
# La aproximación del punto fijo se encuentra dada por 21629550.93589063.
# El valor de la función bajo la aproximación es 1871349812758857.5.
# El error relativo se encuentra dado por 7564663099603698.0.
#
# Resultados de la iteracion 137.
# La aproximación del punto fijo se encuentra dada por -10137897.44360521.
# El valor de la función bajo la aproximación es 411107817825726.44.
# El error relativo se encuentra dado por 1871349844526306.0.
#
# Resultados de la iteracion 138.
# La aproximación del punto fijo se encuentra dada por 628171.2536385413.
# El valor de la función bajo la aproximación es 1578398831102.3645.
# El error relativo se encuentra dado por 411107828591795.1.
#
# Resultados de la iteracion 139.
# La aproximación del punto fijo se encuentra dada por -367114.79752300936.
# El valor de la función bajo la aproximación es 539094071371.32086.
# El error relativo se encuentra dado por 1578399826388.4158.
#
# Resultados de la iteracion 140.
# La aproximación del punto fijo se encuentra dada por 1094890.3362222915.
# El valor de la función bajo la aproximación es 4795138281708.383.
# El error relativo se encuentra dado por 539095533376.4546.
#
# Resultados de la iteracion 141.
# La aproximación del punto fijo se encuentra dada por 538330.5208180421.
# El valor de la función bajo la aproximación es 1159196901927.3262.
# El error relativo se encuentra dado por 4795138838268.198.
#
# Resultados de la iteracion 142.
# La aproximación del punto fijo se encuentra dada por -158907.3814976355.
# El valor de la función bajo la aproximación es 101006726458.50458.
# El error relativo se encuentra dado por 1159197599165.2285.
#
# Resultados de la iteracion 143.
# La aproximación del punto fijo se encuentra dada por -60306.33966751714.
# El valor de la función bajo la aproximación es 14547646854.134962.
# El error relativo se encuentra dado por 101006825059.5464.
#
# Resultados de la iteracion 144.
# La aproximación del punto fijo se encuentra dada por 28547.744461241353.
# El valor de la función bajo la aproximación es 3260008565.1532497.
# El error relativo se encuentra dado por 14547735708.219091.
#
# Resultados de la iteracion 145.
# La aproximación del punto fijo se encuentra dada por -2888.634426966055.
# El valor de la función bajo la aproximación es 33376142.35371585.
# El error relativo se encuentra dado por 3260040001.532138.
#
# Resultados de la iteracion 146.
# La aproximación del punto fijo se encuentra dada por -1443.0157659411084.
# El valor de la función bajo la aproximación es 8326180.9781557415.
# El error relativo se encuentra dado por 33377587.97237687.
#
# Resultados de la iteracion 147.
# La aproximación del punto fijo se encuentra dada por -664.9326868062983.
# El valor de la función bajo la aproximación es 1769784.314155398.
# El error relativo se encuentra dado por 8326959.0612348765.
#
# Resultados de la iteracion 148.
# La aproximación del punto fijo se encuentra dada por -312.04889114302233.
# El valor de la función bajo la aproximación es 388857.27948125574.
# El error relativo se encuentra dado por 1770137.1979510612.
#
# Resultados de la iteracion 149.
# La aproximación del punto fijo se encuentra dada por -144.09312897233406.
# El valor de la función bajo la aproximación es 83579.23461811284.
# El error relativo se encuentra dado por 389025.2352434264.
#
# Resultados de la iteracion 150.
# La aproximación del punto fijo se encuentra dada por -41.74363803334653.
# El valor de la función bajo la aproximación es 6867.483447113445.
# El error relativo se encuentra dado por 83681.58410905182.
#
# Resultados de la iteracion 151.
# La aproximación del punto fijo se encuentra dada por -18.35716059464578.
# El valor de la función bajo la aproximación es 1414.1999597656218.
# El error relativo se encuentra dado por 6890.869924552147.
#
# Resultados de la iteracion 152.
# La aproximación del punto fijo se encuentra dada por -5.878809409605369.
# El valor de la función bajo la aproximación es 161.5506919126465.
# El error relativo se encuentra dado por 1426.678310950662.
#
# Resultados de la iteracion 153.
# La aproximación del punto fijo se encuentra dada por -1.6152948204030606.
# El valor de la función bajo la aproximación es 10.15324917633806.
# El error relativo se encuentra dado por 165.81420650184882.
#
# Resultados de la iteracion 154.
# La aproximación del punto fijo se encuentra dada por 1630.8056472211783.
# El valor de la función bajo la aproximación es 10644304.039288376.
# El error relativo se encuentra dado por 1642.5741912179194.
#
# Resultados de la iteracion 155.
# La aproximación del punto fijo se encuentra dada por -745.3337901728391.
# El valor de la función bajo la aproximación es 2219963.7037155083.
# El error relativo se encuentra dado por 10646680.17872577.
#
# Resultados de la iteracion 156.
# La aproximación del punto fijo se encuentra dada por -307.0737828073425.
# El valor de la función bajo la aproximación es 378031.9336019066.
# El error relativo se encuentra dado por 2220401.963722874.
#
# Resultados de la iteracion 157.
# La aproximación del punto fijo se encuentra dada por -128.4334921391998.
# El valor de la función bajo la aproximación es 65503.75182416837.
# El error relativo se encuentra dado por 378210.5738925747.
#
# Resultados de la iteracion 158.
# La aproximación del punto fijo se encuentra dada por 73.28904949500938.
# El valor de la función bajo la aproximación es 21635.97899674469.
# El error relativo se encuentra dado por 65705.47436580258.
#
# Resultados de la iteracion 159.
# La aproximación del punto fijo se encuentra dada por -444.81949126855625.
# El valor de la función bajo la aproximación es 791956.4492930792.
# El error relativo se encuentra dado por 22154.087537508254.
#
# Resultados de la iteracion 160.
# La aproximación del punto fijo se encuentra dada por -217.85980390045157.
# El valor de la función bajo la aproximación es 189448.90775269014.
# El error relativo se encuentra dado por 792183.4089804473.
#
# Resultados de la iteracion 161.
# La aproximación del punto fijo se encuentra dada por -102.38119044514096.
# El valor de la función bajo la aproximación es 41814.83495599282.
# El error relativo se encuentra dado por 189564.38636614545.
#
# Resultados de la iteracion 162.
# La aproximación del punto fijo se encuentra dada por 2537.204955649708.
# El valor de la función bajo la aproximación es 25745976.76327303.
# El error relativo se encuentra dado por 44454.42110208767.
#
# Resultados de la iteracion 163.
# La aproximación del punto fijo se encuentra dada por -35178.93346932973.
# El valor de la función bajo la aproximación es 4950343879.79846.
# El error relativo se encuentra dado por 25783692.90169801.
#
# Resultados de la iteracion 164.
# La aproximación del punto fijo se encuentra dada por -12940.55724025561.
# El valor de la función bajo la aproximación es 669783239.5990926.
# El error relativo se encuentra dado por 4950366118.174689.
#
# Resultados de la iteracion 165.
# La aproximación del punto fijo se encuentra dada por -3216.3118153485248.
# El valor de la función bajo la aproximación es 41388659.23477385.
# El error relativo se encuentra dado por 669792963.8445175.
#
# Resultados de la iteracion 166.
# La aproximación del punto fijo se encuentra dada por -1240.7670963544192.
# El valor de la función bajo la aproximación es 6153115.813696537.
# El error relativo se encuentra dado por 41390634.77949285.
#
# Resultados de la iteracion 167.
# La aproximación del punto fijo se encuentra dada por 238.6162429873193.
# El valor de la función bajo la aproximación es 226808.3275570318.
# El error relativo se encuentra dado por 6154595.197035879.
#
# Resultados de la iteracion 168.
# La aproximación del punto fijo se encuentra dada por -40.23897969253352.
# El valor de la función bajo la aproximación es 6345.375387145053.
# El error relativo se encuentra dado por 227087.18277971164.
#
# Resultados de la iteracion 169.
# La aproximación del punto fijo se encuentra dada por 52.51135554186918.
# El valor de la función bajo la aproximación es 11161.82039381741.
# El error relativo se encuentra dado por 6438.1257223794555.
#
# Resultados de la iteracion 170.
# La aproximación del punto fijo se encuentra dada por 23.019447645673004.
# El valor de la función bajo la aproximación es 2167.650543554719.
# El error relativo se encuentra dado por 11191.312301713606.
#
# Resultados de la iteracion 171.
# La aproximación del punto fijo se encuentra dada por -137.34720172932822.
# El valor de la función bajo la aproximación es 75806.64644364147.
# El error relativo se encuentra dado por 2328.0171929297203.
#
# Resultados de la iteracion 172.
# La aproximación del punto fijo se encuentra dada por -59.86148617037912.
# El valor de la función bajo la aproximación es 14099.587597346592.
# El error relativo se encuentra dado por 75884.13215920042.
#
# Resultados de la iteracion 173.
# La aproximación del punto fijo se encuentra dada por -8.707839563333579.
# El valor de la función bajo la aproximación es 278.1857630872478.
# El error relativo se encuentra dado por 14150.741243953637.
#
# Resultados de la iteracion 174.
# La aproximación del punto fijo se encuentra dada por 16.789525866365185.
# El valor de la función bajo la aproximación es 1159.555347381683.
# El error relativo se encuentra dado por 303.68312851694657.
#
# Resultados de la iteracion 175.
# La aproximación del punto fijo se encuentra dada por -126.38996343188336.
# El valor de la función bajo la aproximación es 64276.79887893811.
# El error relativo se encuentra dado por 1302.7348366799315.
#
# Resultados de la iteracion 176.
# La aproximación del punto fijo se encuentra dada por 249.86228718670668.
# El valor de la función bajo la aproximación es 249619.25590861004.
# El error relativo se encuentra dado por 64653.051129556705.
#
# Resultados de la iteracion 177.
# La aproximación del punto fijo se encuentra dada por -44544.29947027724.
# El valor de la función bajo la aproximación es 7936610650.516443.
# El error relativo se encuentra dado por 294413.417666074.
#
# Resultados de la iteracion 178.
# La aproximación del punto fijo se encuentra dada por 22549.836078491222.
# El valor de la función bajo la aproximación es 2033901974.322468.
# El error relativo se encuentra dado por 7936677744.651992.
#
# Resultados de la iteracion 179.
# La aproximación del punto fijo se encuentra dada por -21961.863878364034.
# El valor de la función bajo la aproximación es 1929247164.9998188.
# El error relativo se encuentra dado por 2033946486.022425.
#
# Resultados de la iteracion 180.
# La aproximación del punto fijo se encuentra dada por 121602.9929491547.
# El valor de la función bajo la aproximación es 59149250446.56371.
# El error relativo se encuentra dado por 1929390729.8566463.
#
# Resultados de la iteracion 181.
# La aproximación del punto fijo se encuentra dada por -5703441.710439749.
# El valor de la función bajo la aproximación es 130117010633946.6.
# El error relativo se encuentra dado por 59155075491.267105.
#
# Resultados de la iteracion 182.
# La aproximación del punto fijo se encuentra dada por -1519383.1744845733.
# El valor de la función bajo la aproximación es 9234097581503.846.
# El error relativo se encuentra dado por 130117014818005.12.
#
# Resultados de la iteracion 183.
# La aproximación del punto fijo se encuentra dada por 7701343.216105957.
# El valor de la función bajo la aproximación es 237242732612347.16.
# El error relativo se encuentra dado por 9234106802230.236.
#
# Resultados de la iteracion 184.
# La aproximación del punto fijo se encuentra dada por -40418668.47823632.
# El valor de la función bajo la aproximación es 6534675165110564.0.
# El error relativo se encuentra dado por 237242780732358.84.
#
# Resultados de la iteracion 185.
# La aproximación del punto fijo se encuentra dada por -16325927.560871605.
# El valor de la función bajo la aproximación es 1066143701648582.5.
# El error relativo se encuentra dado por 6534675189203305.0.
#
# Resultados de la iteracion 186.
# La aproximación del punto fijo se encuentra dada por 12641168.927569665.
# El valor de la función bajo la aproximación es 639196657534679.6.
# El error relativo se encuentra dado por 1066143730615679.0.
#
# Resultados de la iteracion 187.
# La aproximación del punto fijo se encuentra dada por -1944621.473661812.
# El valor de la función bajo la aproximación es 15126216374385.252.
# El error relativo se encuentra dado por 639196672120470.0.
#
# Resultados de la iteracion 188.
# La aproximación del punto fijo se encuentra dada por 4217762.491177714.
# El valor de la función bajo la aproximación es 71158081806542.1.
# El error relativo se encuentra dado por 15126222536769.217.
#
# Resultados de la iteracion 189.
# La aproximación del punto fijo se encuentra dada por -388641689517.8176.
# El valor de la función bajo la aproximación es 6.041694513241706e+23.
# El error relativo se encuentra dado por 71546727713822.4.
#
# Resultados de la iteracion 190.
# La aproximación del punto fijo se encuentra dada por 1799517485053.336.
# El valor de la función bajo la aproximación es 1.2953052716057762e+25.
# El error relativo se encuentra dado por 6.041694513263587e+23.
#
# Resultados de la iteracion 191.
# La aproximación del punto fijo se encuentra dada por -489444050595.3672.
# El valor de la función bajo la aproximación es 9.582219146537186e+23.
# El error relativo se encuentra dado por 1.2953052716060052e+25.
#
# Resultados de la iteracion 192.
# La aproximación del punto fijo se encuentra dada por 3711416664988.6616.
# El valor de la función bajo la aproximación es 5.509845464463514e+25.
# El error relativo se encuentra dado por 9.582219146579195e+23.
#
# Resultados de la iteracion 193.
# La aproximación del punto fijo se encuentra dada por -3637969798218.8667.
# El valor de la función bajo la aproximación es 5.293929701099688e+25.
# El error relativo se encuentra dado por 5.509845464464249e+25.
#
# Resultados de la iteracion 194.
# La aproximación del punto fijo se encuentra dada por -952278195543.4517.
# El valor de la función bajo la aproximación es 3.6273350468273474e+24.
# El error relativo se encuentra dado por 5.293929701099957e+25.
#
# Resultados de la iteracion 195.
# La aproximación del punto fijo se encuentra dada por 2515589628315.6025.
# El valor de la función bajo la aproximación es 2.5312764712349323e+25.
# El error relativo se encuentra dado por 3.627335046830815e+24.
#
# Resultados de la iteracion 196.
# La aproximación del punto fijo se encuentra dada por 1067289677872.4402.
# El valor de la función bajo la aproximación es 4.556429025974856e+24.
# El error relativo se encuentra dado por 2.531276471235077e+25.
#
# Resultados de la iteracion 197.
# La aproximación del punto fijo se encuentra dada por 470418025278.079.
# El valor de la función bajo la aproximación es 8.851724740279473e+23.
# El error relativo se encuentra dado por 4.556429025975453e+24.
#
# Resultados de la iteracion 198.
# La aproximación del punto fijo se encuentra dada por -128624913368.7732.
# El valor de la función bajo la aproximación es 6.617747335606839e+22.
# El error relativo se encuentra dado por 8.851724740285463e+23.
#
# Resultados de la iteracion 199.
# La aproximación del punto fijo se encuentra dada por 158039096404.73694.
# El valor de la función bajo la aproximación es 9.990542397023569e+22.
# El error relativo se encuentra dado por 6.617747335635505e+22.
#
# Resultados de la iteracion 200.
# La aproximación del punto fijo se encuentra dada por -184265307218.57617.
# El valor de la función bajo la aproximación es 1.358148137777258e+23.
# El error relativo se encuentra dado por 9.9905423970578e+22.
#
# Resultados de la iteracion 201.
# La aproximación del punto fijo se encuentra dada por 1932556281674.5042.
# El valor de la función bajo la aproximación es 1.4939095127356393e+25.
# El error relativo se encuentra dado por 1.3581481377984262e+23.
#
# Resultados de la iteracion 202.
# La aproximación del punto fijo se encuentra dada por -57899904907732.2.
# El valor de la función bajo la aproximación es 1.34095959532977e+28.
# El error relativo se encuentra dado por 1.4939095127416226e+25.
#
# Resultados de la iteracion 203.
# La aproximación del punto fijo se encuentra dada por 7104844698300134.0.
# El valor de la función bajo la aproximación es 2.0191527274785404e+32.
# El error relativo se encuentra dado por 1.3409595953304861e+28.
#
# Resultados de la iteracion 204.
# La aproximación del punto fijo se encuentra dada por 2801154525767352.0.
# El valor de la función bajo la aproximación es 3.1385866708907665e+31.
# El error relativo se encuentra dado por 2.0191527274785404e+32.
#
# Resultados de la iteracion 205.
# La aproximación del punto fijo se encuentra dada por -531546011304913.0.
# El valor de la función bajo la aproximación es 1.1301646485366493e+30.
# El error relativo se encuentra dado por 3.138586670890767e+31.
#
# Resultados de la iteracion 206.
# La aproximación del punto fijo se encuentra dada por 1075259547395147.2.
# El valor de la función bajo la aproximación es 4.6247323770576666e+30.
# El error relativo se encuentra dado por 1.1301646485366508e+30.
#
# Resultados de la iteracion 207.
# La aproximación del punto fijo se encuentra dada por -2.462921126556943e+16.
# ...
# El valor de la función bajo la aproximación es 4.5151750318416677e+282.
# El error relativo se encuentra dado por 1.8069966110825282e+283.
#
# Resultados de la iteracion 11366.
# La aproximación del punto fijo se encuentra dada por 2.0334309039781258e+142.
# El valor de la función bajo la aproximación es 1.653936496501319e+285.
# El error relativo se encuentra dado por 4.5151750318416677e+282.
#
# Resultados de la iteracion 11367.
# La aproximación del punto fijo se encuentra dada por -6.582259032921768e+142.
# El valor de la función bajo la aproximación es 1.7330453590592084e+286.
# El error relativo se encuentra dado por 1.653936496501319e+285.
#
# Resultados de la iteracion 11368.
# La aproximación del punto fijo se encuentra dada por 1.7649746082657102e+145.
# El valor de la función bajo la aproximación es 1.2460541471290788e+291.
# El error relativo se encuentra dado por 1.7330453590592084e+286.
#
# Resultados de la iteracion 11369.
# La aproximación del punto fijo se encuentra dada por -1.9172091159925056e+145.
# El valor de la función bajo la aproximación es 1.470276317777906e+291.
# El error relativo se encuentra dado por 1.2460541471290788e+291.
#
# Resultados de la iteracion 11370.
# La aproximación del punto fijo se encuentra dada por -8.670630672942384e+144.
# El valor de la función bajo la aproximación es 3.007193450662772e+290.
# El error relativo se encuentra dado por 1.470276317777906e+291.
#
# Resultados de la iteracion 11371.
# La aproximación del punto fijo se encuentra dada por -2.2856313505501372e+144.
# El valor de la función bajo la aproximación es 2.0896442682470576e+289.
# El error relativo se encuentra dado por 3.007193450662772e+290.
#
# Resultados de la iteracion 11372.
# La aproximación del punto fijo se encuentra dada por 8.315254256217374e+143.
# El valor de la función bajo la aproximación es 2.7657381338216465e+288.
# El error relativo se encuentra dado por 2.0896442682470576e+289.
#
# Resultados de la iteracion 11373.
# La aproximación del punto fijo se encuentra dada por -1.0589115277311108e+144.
# El valor de la función bajo la aproximación es 4.4851744942473395e+288.
# El error relativo se encuentra dado por 2.7657381338216465e+288.
#
# Resultados de la iteracion 11374.
# La aproximación del punto fijo se encuentra dada por 1.8782652471068754e+147.
# El valor de la función bajo la aproximación es 1.4111521353957807e+295.
# El error relativo se encuentra dado por 4.4851744942473395e+288.
#
# Resultados de la iteracion 11375.
# La aproximación del punto fijo se encuentra dada por 9.331228279710072e+146.
# El valor de la función bajo la aproximación es 3.48287284832244e+294.
# El error relativo se encuentra dado por 1.4111521353957807e+295.
#
# Resultados de la iteracion 11376.
# La aproximación del punto fijo se encuentra dada por 4.214109890107301e+146.
# El valor de la función bajo la aproximación es 7.103488866360067e+293.
# El error relativo se encuentra dado por 3.48287284832244e+294.
#
# Resultados de la iteracion 11377.
# La aproximación del punto fijo se encuentra dada por 2.0384983585956313e+146.
# El valor de la función bajo la aproximación es 1.6621902231988333e+293.
# El error relativo se encuentra dado por 7.103488866360067e+293.
#
# Resultados de la iteracion 11378.
# La aproximación del punto fijo se encuentra dada por -1.421140337394964e+148.
# El valor de la función bajo la aproximación es 8.07855943428429e+296.
# El error relativo se encuentra dado por 1.6621902231988333e+293.
#
# Resultados de la iteracion 11379.
# La aproximación del punto fijo se encuentra dada por 2.0136937681719326e+148.
# El valor de la función bajo la aproximación es 1.6219850367897908e+297.
# El error relativo se encuentra dado por 8.07855943428429e+296.
#
# Resultados de la iteracion 11380.
# La aproximación del punto fijo se encuentra dada por 8.861460930960137e+147.
# El valor de la función bajo la aproximación es 3.1410195932373157e+296.
# El error relativo se encuentra dado por 1.6219850367897908e+297.
#
# Resultados de la iteracion 11381.
# La aproximación del punto fijo se encuentra dada por -4.495965276502359e+148.
# El valor de la función bajo la aproximación es 8.085481507005973e+297.
# El error relativo se encuentra dado por 3.1410195932373157e+296.
#
# Resultados de la iteracion 11382.
# La aproximación del punto fijo se encuentra dada por -2.2046122569195342e+148.
# El valor de la función bajo la aproximación es 1.9441260813439368e+297.
# El error relativo se encuentra dado por 8.085481507005973e+297.
#
# Resultados de la iteracion 11383.
# La aproximación del punto fijo se encuentra dada por 9.197544406756775e+148.
# El valor de la función bajo la aproximación es 3.3837929245705132e+298.
# El error relativo se encuentra dado por 1.9441260813439368e+297.
#
# Resultados de la iteracion 11384.
# La aproximación del punto fijo se encuentra dada por -3.017495141575678e+150.
# El valor de la función bajo la aproximación es 3.642110771773129e+301.
# El error relativo se encuentra dado por 3.3837929245705132e+298.
#
# Resultados de la iteracion 11385.
# La aproximación del punto fijo se encuentra dada por -6.1146090243977785e+149.
# El valor de la función bajo la aproximación es 1.49553774084987e+300.
# El error relativo se encuentra dado por 3.642110771773129e+301.
#
# Resultados de la iteracion 11386.
# La aproximación del punto fijo se encuentra dada por -2.6750592204281414e+149.
# El valor de la función bajo la aproximación es 2.8623767331190463e+299.
# El error relativo se encuentra dado por 1.49553774084987e+300.
#
# Resultados de la iteracion 11387.
# La aproximación del punto fijo se encuentra dada por -1.1800631826118866e+149.
# El valor de la función bajo la aproximación es 5.570196459824379e+298.
# El error relativo se encuentra dado por 2.8623767331190463e+299.
#
# Resultados de la iteracion 11388.
# La aproximación del punto fijo se encuentra dada por 2.8850484831049447e+148.
# El valor de la función bajo la aproximación es 3.3294018999464567e+297.
# El error relativo se encuentra dado por 5.570196459824379e+298.
#
# Resultados de la iteracion 11389.
# La aproximación del punto fijo se encuentra dada por 1.416152963507297e+148.
# El valor de la función bajo la aproximación es 8.021956864201998e+296.
# El error relativo se encuentra dado por 3.3294018999464567e+297.
#
# Resultados de la iteracion 11390.
# La aproximación del punto fijo se encuentra dada por 4.7991804146902474e+147.
# El valor de la función bajo la aproximación es 9.212853061098581e+295.
# El error relativo se encuentra dado por 8.021956864201998e+296.
#
# Resultados de la iteracion 11391.
# La aproximación del punto fijo se encuentra dada por 2.3789832732399757e+147.
# El valor de la función bajo la aproximación es 2.2638245657422357e+295.
# El error relativo se encuentra dado por 9.212853061098581e+295.
#
# Resultados de la iteracion 11392.
# La aproximación del punto fijo se encuentra dada por 1.1894782736266401e+147.
# El valor de la función bajo la aproximación es 5.659434253719248e+294.
# El error relativo se encuentra dado por 2.2638245657422357e+295.
#
# Resultados de la iteracion 11393.
# La aproximación del punto fijo se encuentra dada por 4.378948217943293e+146.
# El valor de la función bajo la aproximación es 7.670074998171496e+293.
# El error relativo se encuentra dado por 5.659434253719248e+294.
#
# Resultados de la iteracion 11394.
# La aproximación del punto fijo se encuentra dada por 1.1608066412347215e+145.
# El valor de la función bajo la aproximación es 5.389888233338542e+290.
# El error relativo se encuentra dado por 7.670074998171496e+293.
#
# Resultados de la iteracion 11395.
# La aproximación del punto fijo se encuentra dada por -3.4706217446057337e+145.
# El valor de la función bajo la aproximación es 4.818086117652059e+291.
# El error relativo se encuentra dado por 5.389888233338542e+290.
#
# Resultados de la iteracion 11396.
# La aproximación del punto fijo se encuentra dada por -1.5338173569804042e+145.
# El valor de la función bajo la aproximación es 9.41038273829741e+290.
# El error relativo se encuentra dado por 4.818086117652059e+291.
#
# Resultados de la iteracion 11397.
# La aproximación del punto fijo se encuentra dada por 2.441349225065545e+145.
# El valor de la función bajo la aproximación es 2.384074415491255e+291.
# El error relativo se encuentra dado por 9.41038273829741e+290.
#
# Resultados de la iteracion 11398.
# La aproximación del punto fijo se encuentra dada por -2.9560917497915686e+145.
# El valor de la función bajo la aproximación es 3.4953913732743113e+291.
# El error relativo se encuentra dado por 2.384074415491255e+291.
#
# Resultados de la iteracion 11399.
# La aproximación del punto fijo se encuentra dada por -1.4707658286193743e+145.
# El valor de la función bajo la aproximación es 8.652608490537738e+290.
# El error relativo se encuentra dado por 3.4953913732743113e+291.
#
# Resultados de la iteracion 11400.
# La aproximación del punto fijo se encuentra dada por 1.40689743375824e+147.
# El valor de la función bajo la aproximación es 7.917441556462085e+294.
# El error relativo se encuentra dado por 8.652608490537738e+290.
#
# Resultados de la iteracion 11401.
# La aproximación del punto fijo se encuentra dada por 2.6965241898585336e+146.
# El valor de la función bajo la aproximación es 2.9084970825968886e+293.
# El error relativo se encuentra dado por 7.917441556462085e+294.
#
# Resultados de la iteracion 11402.
# La aproximación del punto fijo se encuentra dada por -1.9385634266937668e+146.
# El valor de la función bajo la aproximación es 1.5032112637258717e+293.
# El error relativo se encuentra dado por 2.9084970825968886e+293.
#
# Resultados de la iteracion 11403.
# La aproximación del punto fijo se encuentra dada por -8.11450785226471e+145.
# El valor de la función bajo la aproximación es 2.633809507378625e+292.
# El error relativo se encuentra dado por 1.5032112637258717e+293.
#
# Resultados de la iteracion 11404.
# La aproximación del punto fijo se encuentra dada por -3.574083345408409e+145.
# El valor de la función bajo la aproximación es 5.109628703970307e+291.
# El error relativo se encuentra dado por 2.633809507378625e+292.
#
# Resultados de la iteracion 11405.
# La aproximación del punto fijo se encuentra dada por -1.5570458858387675e+145.
# El valor de la función bajo la aproximación es 9.697567562429728e+290.
# El error relativo se encuentra dado por 5.109628703970307e+291.
#
# Resultados de la iteracion 11406.
# La aproximación del punto fijo se encuentra dada por -3.7746141521864426e+144.
# El valor de la función bajo la aproximación es 5.699084799154471e+289.
# El error relativo se encuentra dado por 9.697567562429728e+290.
#
# Resultados de la iteracion 11407.
# La aproximación del punto fijo se encuentra dada por -1.7549288513690456e+144.
# El valor de la función bajo la aproximación es 1.2319101093469911e+289.
# El error relativo se encuentra dado por 5.699084799154471e+289.
#
# Resultados de la iteracion 11408.
# La aproximación del punto fijo se encuentra dada por -7.294714693770732e+143.
# El valor de la función bajo la aproximación es 2.1285144985405852e+288.
# El error relativo se encuentra dado por 1.2319101093469911e+289.
#
# Resultados de la iteracion 11409.
# La aproximación del punto fijo se encuentra dada por 1.6842211897927188e+144.
# El valor de la función bajo la aproximación es 1.1346404064587204e+289.
# El error relativo se encuentra dado por 2.1285144985405852e+288.
#
# Resultados de la iteracion 11410.
# La aproximación del punto fijo se encuentra dada por -1.2616057030389578e+145.
# El valor de la función bajo la aproximación es 6.366595799761692e+290.
# El error relativo se encuentra dado por 1.1346404064587204e+289.
#
# Resultados de la iteracion 11411.
# La aproximación del punto fijo se encuentra dada por 6.059758865307829e+146.
# El valor de la función bajo la aproximación es 1.4688271002270732e+294.
# El error relativo se encuentra dado por 6.366595799761692e+290.
#
# Resultados de la iteracion 11412.
# La aproximación del punto fijo se encuentra dada por 3.028466078961826e+146.
# El valor de la función bajo la aproximación es 3.6686427165689665e+293.
# El error relativo se encuentra dado por 1.4688271002270732e+294.
#
# Resultados de la iteracion 11413.
# La aproximación del punto fijo se encuentra dada por -6.595329769289837e+146.
# El valor de la función bajo la aproximación es 1.7399349906272293e+294.
# El error relativo se encuentra dado por 3.6686427165689665e+293.
#
# Resultados de la iteracion 11414.
# La aproximación del punto fijo se encuentra dada por -2.6868099462767985e+146.
# El valor de la función bajo la aproximación es 2.887579074964773e+293.
# El error relativo se encuentra dado por 1.7399349906272293e+294.
#
# Resultados de la iteracion 11415.
# La aproximación del punto fijo se encuentra dada por 3.29124233440033e+147.
# El valor de la función bajo la aproximación es 4.332910441499574e+295.
# El error relativo se encuentra dado por 2.887579074964773e+293.
#
# Resultados de la iteracion 11416.
# La aproximación del punto fijo se encuentra dada por -4.393897386255269e+147.
# El valor de la función bajo la aproximación es 7.722533696376355e+295.
# El error relativo se encuentra dado por 4.332910441499574e+295.
#
# Resultados de la iteracion 11417.
# La aproximación del punto fijo se encuentra dada por -1.1442406870386993e+147.
# El valor de la función bajo la aproximación es 5.237146999499179e+294.
# El error relativo se encuentra dado por 7.722533696376355e+295.
#
# Resultados de la iteracion 11418.
# La aproximación del punto fijo se encuentra dada por -5.608084599285658e+146.
# El valor de la función bajo la aproximación es 1.2580245149097992e+294.
# El error relativo se encuentra dado por 5.237146999499179e+294.
#
# Resultados de la iteracion 11419.
# La aproximación del punto fijo se encuentra dada por 1.9635967340954763e+147.
# El valor de la función bajo la aproximación es 1.5422848536601683e+295.
# El error relativo se encuentra dado por 1.2580245149097992e+294.
#
# Resultados de la iteracion 11420.
# La aproximación del punto fijo se encuentra dada por -1.6918603142832954e+148.
# El valor de la función bajo la aproximación es 1.1449565292187084e+297.
# El error relativo se encuentra dado por 1.5422848536601683e+295.
#
# Resultados de la iteracion 11421.
# La aproximación del punto fijo se encuentra dada por 6.17904857496535e+147.
# El valor de la función bajo la aproximación es 1.5272256516712528e+296.
# El error relativo se encuentra dado por 1.1449565292187084e+297.
#
# Resultados de la iteracion 11422.
# La aproximación del punto fijo se encuentra dada por -4.501652256340048e+148.
# El valor de la función bajo la aproximación es 8.105949214804578e+297.
# El error relativo se encuentra dado por 1.5272256516712528e+296.
#
# Resultados de la iteracion 11423.
# La aproximación del punto fijo se encuentra dada por 2.7687405271254636e+148.
# El valor de la función bajo la aproximación es 3.066369642618796e+297.
# El error relativo se encuentra dado por 8.105949214804578e+297.
#
# Resultados de la iteracion 11424.
# La aproximación del punto fijo se encuentra dada por -3.501039258815493e+149.
# El valor de la función bajo la aproximación es 4.902910356706934e+299.
# El error relativo se encuentra dado por 3.066369642618796e+297.
#
# Resultados de la iteracion 11425.
# La aproximación del punto fijo se encuentra dada por 1.929067817928869e+153.
# El valor de la función bajo la aproximación es 1.488521058467539e+307.
# El error relativo se encuentra dado por 4.902910356706934e+299.
#
# Resultados de la iteracion 11426.
# La aproximación del punto fijo se encuentra dada por -2.379856634557199e+154.
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-25-a5e7a859d0b5> in <module>
#      31             print('Resultados de la iteracion {0}.'.format(k))
#      32             print('La aproximación del punto fijo se encuentra dada por {0}.'.format(itera[1]))
# ---> 33             print('El valor de la función bajo la aproximación es {0}.'.format(fx(itera[1])))
#      34
#      35             # Actualizamos las variables
#
# <ipython-input-22-c003874eec24> in fx(x)
#       1 # Definimos la funcion objetivo
#       2 def fx(x):
# ----> 3     fx = cos(2*x)-(4*x)*cos(x)+(2*x)**2+1
#       4     return fx
#       5
#
# OverflowError: (34, 'Result too large')
